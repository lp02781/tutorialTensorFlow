# %%
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers

df=pd.read_csv('~/tutorialTensorFlow/iris_train.csv') 
data_raw_x = df[['sep_l','sep_w','pet_l','pet_w']]

data_x = data_raw_x.values
data_y = pd.factorize(df.classes)[0]

class_names = ['Iris-setosa','Iris-versicolor','Iris-virginica']

model1 = tf.keras.Sequential()
model1.add(layers.Dense(128,activation = 'relu',input_shape=data_x[0].shape))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(3,activation = 'softmax'))
model1.summary()

ep = 10
model1.compile(optimizer=tf.keras.optimizers.Adam(lr =0.0001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model1.fit(data_x, data_y,batch_size=1, epochs=ep)

dt=pd.read_csv('~/tutorialTensorFlow/iris_test.csv') 
test_raw_x = df[['sep_l','sep_w','pet_l','pet_w']]

x_test = test_raw_x.values
y_test = pd.factorize(dt.classes)[0]

test_loss, test_accuracy = model1.evaluate(x_test,  y_test, verbose=2)

predictions = model1.predict(x_test)

print(predictions)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 128)               640
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_17 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 67,075
# Trainable params: 67,075
# Non-trainable params: 0
# _________________________________________________________________
# Train on 75 samples
# Epoch 1/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 1.0609 - accuracy: 0.4800
# Epoch 2/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 1.0003 - accuracy: 0.8000
# Epoch 3/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.9220 - accuracy: 0.7867
# Epoch 4/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.8639 - accuracy: 0.7333
# Epoch 5/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.8126 - accuracy: 0.9200
# Epoch 6/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.7814 - accuracy: 0.8533
# Epoch 7/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.7436 - accuracy: 0.9333
# Epoch 8/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.7186 - accuracy: 0.8800
# Epoch 9/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.7117 - accuracy: 0.8800
# Epoch 10/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.6862 - accuracy: 0.8800
# 75/75 - 0s - loss: 1.1768 - accuracy: 0.3600
# [[9.9506086e-01 4.9254643e-03 1.3584735e-05]
#  [2.2251053e-02 9.6993726e-01 7.8117014e-03]
#  [1.4555514e-02 9.6820271e-01 1.7241841e-02]
#  [1.1269404e-03 5.1620001e-01 4.8267302e-01]
#  [8.7207751e-03 9.0139294e-01 8.9886248e-02]
#  [7.7046296e-03 9.6537536e-01 2.6920056e-02]
#  [1.1615492e-03 6.0981095e-01 3.8902751e-01]
#  [1.6595345e-02 9.7847396e-01 4.9307453e-03]
#  [7.3531462e-04 4.0435439e-01 5.9491032e-01]
#  [6.5335928e-04 4.0984431e-01 5.8950233e-01]
#  [2.7934560e-03 7.5051355e-01 2.4669294e-01]
#  [9.8918438e-01 1.0758338e-02 5.7313835e-05]
#  [9.9095041e-01 9.0086646e-03 4.1033243e-05]
#  [1.1677523e-01 8.7631238e-01 6.9124619e-03]
#  [2.1838760e-02 9.6293885e-01 1.5222368e-02]
#  [9.2852600e-02 8.9905900e-01 8.0883401e-03]
#  [9.9523699e-01 4.7495314e-03 1.3423620e-05]
#  [9.9525529e-01 4.7316565e-03 1.3027272e-05]
#  [1.8254019e-02 9.4229406e-01 3.9451897e-02]
#  [2.1856255e-03 8.8307720e-01 1.1473723e-01]
#  [9.8656929e-01 1.3339850e-02 9.0914058e-05]
#  [9.9722230e-01 2.7726106e-03 5.1589736e-06]
#  [9.9380231e-01 6.1772554e-03 2.0361016e-05]
#  [8.7936157e-03 9.2405373e-01 6.7152649e-02]
