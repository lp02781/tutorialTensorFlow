# %%
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers

df=pd.read_csv('~/tutorialTensorFlow/iris_train.csv') 
data_raw_x = df[['sep_l','sep_w','pet_l','pet_w']]

data_x = data_raw_x.values
data_y = pd.factorize(df.classes)[0]

class_names = ['Iris-setosa','Iris-versicolor','Iris-virginica']

model1 = tf.keras.Sequential()
model1.add(layers.Dense(128,activation = 'relu',input_shape=data_x[0].shape))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(3,activation = 'softmax'))
model1.summary()

ep = 10
model1.compile(optimizer=tf.keras.optimizers.Adam(lr =0.0001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model1.fit(data_x, data_y,batch_size=1, epochs=ep)

dt=pd.read_csv('~/tutorialTensorFlow/iris_test.csv') 
test_raw_x = df[['sep_l','sep_w','pet_l','pet_w']]

x_test = test_raw_x.values
y_test = pd.factorize(dt.classes)[0]

test_loss, test_accuracy = model1.evaluate(x_test,  y_test, verbose=2)

predictions = model1.predict(x_test)

print(predictions)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               640
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 67,075
# Trainable params: 67,075
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# /home/mfikih15/tutorialTensorFlow/Env/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /home/mfikih15/tutorialTensorFlow/Env/lib/python3.6/site-packages/tensorflow/python/keras/backend.py:4930: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 75/75 [==============================] - 0s 894us/step - loss: 1.0202 - accuracy: 0.4400
# Epoch 2/10
# 75/75 [==============================] - 0s 1ms/step - loss: 0.8725 - accuracy: 0.7067
# Epoch 3/10
# 75/75 [==============================] - 0s 2ms/step - loss: 0.6842 - accuracy: 0.8000
# Epoch 4/10
# 75/75 [==============================] - 0s 1ms/step - loss: 0.5166 - accuracy: 0.8667
# Epoch 5/10
# 75/75 [==============================] - 0s 1ms/step - loss: 0.4057 - accuracy: 0.8800
# Epoch 6/10
# 75/75 [==============================] - 0s 1ms/step - loss: 0.3440 - accuracy: 0.9067
# Epoch 7/10
# 75/75 [==============================] - 0s 1ms/step - loss: 0.2862 - accuracy: 0.8933
# Epoch 8/10
# 75/75 [==============================] - 0s 1ms/step - loss: 0.2404 - accuracy: 0.9600
# Epoch 9/10
# 75/75 [==============================] - 0s 996us/step - loss: 0.2396 - accuracy: 0.9200
# Epoch 10/10
# 75/75 [==============================] - 0s 1ms/step - loss: 0.2266 - accuracy: 0.8800
# 3/3 - 0s - loss: 3.7365 - accuracy: 0.3200
# [[9.95559454e-01 4.40064119e-03 3.99259006e-05]
#  [1.23212757e-02 9.59503710e-01 2.81749293e-02]
#  [8.84976145e-03 8.66387248e-01 1.24762997e-01]
#  [9.93299531e-04 2.03235194e-01 7.95771539e-01]
#  [6.34629605e-03 5.73989511e-01 4.19664234e-01]
#  [1.00153489e-02 9.08448875e-01 8.15357566e-02]
#  [3.31874850e-04 1.00783616e-01 8.98884535e-01]
#  [8.51772819e-03 9.71606791e-01 1.98754519e-02]
#  [3.08526331e-04 7.62504861e-02 9.23440993e-01]
#  [2.54910090e-04 7.36293122e-02 9.26115692e-01]
#  [2.12793262e-03 3.35557818e-01 6.62314177e-01]
#  [9.89130020e-01 1.07064284e-02 1.63538469e-04]
#  [9.92384911e-01 7.51960138e-03 9.54593852e-05]
#  [6.92745447e-02 9.10965025e-01 1.97604038e-02]
#  [1.37636475e-02 9.20491636e-01 6.57446161e-02]
#  [3.26835215e-02 9.36091065e-01 3.12254559e-02]
#  [9.95528162e-01 4.42899531e-03 4.28279927e-05]
#  [9.94485676e-01 5.45848347e-03 5.57999483e-05]
#  [1.39722535e-02 7.88299441e-01 1.97728395e-01]
#  [1.54618639e-03 4.13560271e-01 5.84893584e-01]
#  [9.86805439e-01 1.29566304e-02 2.38000575e-04]
#  [9.97364938e-01 2.61421129e-03 2.08342717e-05]
#  [9.94061649e-01 5.87564241e-03 6.26681358e-05]
