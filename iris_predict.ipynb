# %%
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers

df=pd.read_csv('~/tutorialTensorFlow/iris_train.csv') 
data_raw_x = df[['sep_l','sep_w','pet_l','pet_w']]

data_x = data_raw_x.values
data_y = pd.factorize(df.classes)[0]

class_names = ['Iris-setosa','Iris-versicolor','Iris-virginica']

model1 = tf.keras.Sequential()
model1.add(layers.Dense(128,activation = 'relu',input_shape=data_x[0].shape))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(3,activation = 'softmax'))
model1.summary()

ep = 10
model1.compile(optimizer=tf.keras.optimizers.Adam(lr =0.0001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model1.fit(data_x, data_y,batch_size=1, epochs=ep)

dt=pd.read_csv('~/tutorialTensorFlow/iris_test.csv') 
test_raw_x = df[['sep_l','sep_w','pet_l','pet_w']]

x_test = test_raw_x.values
y_test = pd.factorize(dt.classes)[0]

test_loss, test_accuracy = model1.evaluate(x_test,  y_test, verbose=2)

predictions = model1.predict(x_test)

print(predictions)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_60 (Dense)             (None, 128)               640
# _________________________________________________________________
# dense_61 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_62 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_63 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_64 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_65 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 67,075
# Trainable params: 67,075
# Non-trainable params: 0
# _________________________________________________________________
# Train on 75 samples
# Epoch 1/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 1.0650 - accuracy: 0.4000
# Epoch 2/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 1.0149 - accuracy: 0.5867
# Epoch 3/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.9469 - accuracy: 0.7200
# Epoch 4/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 0.8634 - accuracy: 0.7600
# Epoch 5/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 0.8027 - accuracy: 0.8400
# Epoch 6/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 0.7649 - accuracy: 0.8800
# Epoch 7/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 0.7230 - accuracy: 0.8933
# Epoch 8/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 0.7056 - accuracy: 0.8933
# Epoch 9/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 0.6923 - accuracy: 0.8800
# Epoch 10/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.6659 - accuracy: 0.9333
# 75/75 - 0s - loss: 1.2135 - accuracy: 0.3333
# [[9.97071266e-01 2.90003116e-03 2.85932765e-05]
#  [8.00156686e-03 9.60745394e-01 3.12529765e-02]
#  [7.60840252e-03 9.02292311e-01 9.00993049e-02]
#  [2.91926553e-04 1.21372998e-01 8.78335118e-01]
#  [5.30913752e-03 6.11016870e-01 3.83673906e-01]
#  [4.28414438e-03 8.66876423e-01 1.28839388e-01]
#  [1.74725399e-04 1.04987122e-01 8.94838095e-01]
#  [5.33160241e-03 9.72255647e-01 2.24128198e-02]
#  [1.31637848e-04 6.68343753e-02 9.33033943e-01]
#  [1.09472239e-04 6.25955835e-02 9.37294960e-01]
#  [9.36494034e-04 2.69857734e-01 7.29205728e-01]
#  [9.93076205e-01 6.81342417e-03 1.10349210e-04]
#  [9.94223177e-01 5.69771929e-03 7.90106715e-05]
#  [4.24025245e-02 9.38571215e-01 1.90262776e-02]
#  [1.09669035e-02 9.26984668e-01 6.20483905e-02]
#  [3.12897116e-02 9.42088962e-01 2.66212858e-02]
#  [9.97258902e-01 2.71249446e-03 2.85002607e-05]
#  [9.97255385e-01 2.71647680e-03 2.81531102e-05]
#  [1.09862210e-02 8.13413620e-01 1.75600111e-01]
#  [8.12321436e-04 4.10868883e-01 5.88318884e-01]
#  [9.91102815e-01 8.72916449e-03 1.68014740e-04]
