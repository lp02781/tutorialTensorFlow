# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import tensorflow as tf
from keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
diabetes = datasets.load_diabetes()

# %%
x_train = diabetes.data
y_train = diabetes.target
print(x_train.shape)
print(y_train.shape)
# Out:
# (442, 10)
# (442,)

# %%
model = Sequential()
model.add(Dense(128,input_shape=[x_train.shape[1]]))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate =0.0001),loss='mean_squared_error')

# %%
learn = model.fit(x_train, y_train, epochs=1000, verbose=True)
# Out:
# Epoch 1/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 29074.7871
# Epoch 2/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 29068.3828
# Epoch 3/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 29061.6621
# Epoch 4/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 29053.7383
# Epoch 5/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 29044.5039
# Epoch 6/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 29033.5273
# Epoch 7/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 29019.7578
# Epoch 8/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 29003.5723
# Epoch 9/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 28984.0742
# Epoch 10/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 28960.1523
# Epoch 11/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 28931.2031
# Epoch 12/1000
# ...

# %%
plt.plot(learn.history['loss'],label = 'Training')

# %%
output_predict = model.predict(x_train)

# %%
step_test = 10

# %%
x_label = np.arange(0,step_test,1)

plt.figure()
plt.subplot(311).set_title("1")
plt.plot(x_label, output_predict[:step_test], '-b', x_label, y_train[:step_test], '-r')


plt.show()

# %%
import tensorflow as tf

layer0 = tf.keras.layers.Dense(units=1, input_shape=[x_train.shape[1]])
model = tf.keras.Sequential(layer0)

model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(1), metrics=['accuracy'])

model.fit(x_train, y_train, epochs=100, verbose=True)

predictions = model.predict(x_train)[:, 0]
print(predictions)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 0s 2ms/step - loss: 27034.4844 - accuracy: 0.0000e+00
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 23041.3555 - accuracy: 0.0000e+00
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 19442.2910 - accuracy: 0.0000e+00
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 16427.2031 - accuracy: 0.0000e+00
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 13857.9453 - accuracy: 0.0000e+00
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 11688.4658 - accuracy: 0.0000e+00
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 9966.5830 - accuracy: 0.0000e+00
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 8549.1807 - accuracy: 0.0000e+00
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 7374.7812 - accuracy: 0.0000e+00
# ...
