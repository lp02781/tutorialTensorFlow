# %%
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers

df=pd.read_csv('~/tutorialTensorFlow/iris_train.csv') 
data_raw_x = df[['sep_l','sep_w','pet_l','pet_w']]

data_x = data_raw_x.values
data_y = pd.factorize(df.classes)[0]

class_names = ['Iris-setosa','Iris-versicolor','Iris-virginica']

model1 = tf.keras.Sequential()
model1.add(layers.Dense(128,activation = 'relu',input_shape=data_x[0].shape))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(128,activation = 'relu'))
model1.add(layers.Dense(3,activation = 'softmax'))
model1.summary()

ep = 10
model1.compile(optimizer=tf.keras.optimizers.Adam(lr =0.0001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model1.fit(data_x, data_y,batch_size=1, epochs=ep)

dt=pd.read_csv('~/tutorialTensorFlow/iris_test.csv') 
test_raw_x = df[['sep_l','sep_w','pet_l','pet_w']]

x_test = test_raw_x.values
y_test = pd.factorize(dt.classes)[0]

test_loss, test_accuracy = model1.evaluate(x_test,  y_test, verbose=2)

predictions = model1.predict(x_test)

print(predictions)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 128)               640
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 67,075
# Trainable params: 67,075
# Non-trainable params: 0
# _________________________________________________________________
# Train on 75 samples
# Epoch 1/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 1.0641 - accuracy: 0.4000
# Epoch 2/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.9936 - accuracy: 0.7333
# Epoch 3/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.9107 - accuracy: 0.7200
# Epoch 4/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 0.8379 - accuracy: 0.8267
# Epoch 5/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.7907 - accuracy: 0.8800
# Epoch 6/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.7592 - accuracy: 0.8933
# Epoch 7/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 0.7122 - accuracy: 0.9200
# Epoch 8/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 0.6843 - accuracy: 0.9467
# Epoch 9/10
# 75/75 [==============================] - 0s 2ms/sample - loss: 0.6756 - accuracy: 0.9333
# Epoch 10/10
# 75/75 [==============================] - 0s 1ms/sample - loss: 0.6725 - accuracy: 0.8933
# 75/75 - 0s - loss: 1.2317 - accuracy: 0.3067
# [[9.95745838e-01 4.24706284e-03 7.08382322e-06]
#  [9.14095901e-03 9.48910832e-01 4.19482701e-02]
#  [5.80637204e-03 8.74525189e-01 1.19668476e-01]
#  [1.30198270e-04 5.36458269e-02 9.46224034e-01]
#  [2.97312695e-03 4.73379523e-01 5.23647308e-01]
#  [5.31498063e-03 7.33512163e-01 2.61172861e-01]
#  [6.39309292e-05 4.60970663e-02 9.53839064e-01]
#  [6.16122875e-03 9.63751733e-01 3.00870482e-02]
#  [6.74333933e-05 3.64143737e-02 9.63518202e-01]
#  [5.21808979e-05 3.40456739e-02 9.65902150e-01]
#  [3.59524478e-04 1.20732799e-01 8.78907681e-01]
#  [9.90086734e-01 9.88028012e-03 3.29049726e-05]
#  [9.92139161e-01 7.83736631e-03 2.33764495e-05]
#  [3.98342572e-02 9.39579606e-01 2.05861721e-02]
#  [9.99056548e-03 9.10475016e-01 7.95344412e-02]
#  [2.53203828e-02 9.48388159e-01 2.62914337e-02]
#  [9.95873988e-01 4.11919039e-03 6.84967654e-06]
#  [9.95755315e-01 4.23825206e-03 6.45157934e-06]
#  [9.30663384e-03 7.59110332e-01 2.31582955e-01]
#  [3.61005310e-04 2.09125370e-01 7.90513635e-01]
#  [9.87783015e-01 1.21633811e-02 5.35837789e-05]
#  [9.97636437e-01 2.36126781e-03 2.30069963e-06]
